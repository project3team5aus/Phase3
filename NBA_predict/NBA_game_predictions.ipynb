# %% [markdown]
# ## Script to generate NBA game predictions for 2018-2019 season

# %%
# Dependencies
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np
import os
import bs4
import splinter
from bs4 import BeautifulSoup
from splinter import Browser
import requests
import pymongo
import re
import time
import datetime
from datetime import date
import sqlalchemy
from sqlalchemy import create_engine

# %% [markdown]
# Step 1: Machine Learning Model using SVM linear classifier

# %%
# Read in dataset that has regular season game data from 2012-2018
df = pd.read_csv("db/2012-18_teamBoxScore_diff_columns.csv")
df.head()
# Out:
#        gmDate gmTime  seasTyp    offLNm1 offFNm1    offLNm2  offFNm2  \
# 0  10/30/2012  19:00  Regular   Brothers    Tony      Smith  Michael
# 1  10/30/2012  19:00  Regular   Brothers    Tony      Smith  Michael
# 2  10/30/2012  20:00  Regular  McCutchen   Monty     Wright     Sean
# 3  10/30/2012  20:00  Regular  McCutchen   Monty     Wright     Sean
# 4  10/30/2012  22:30  Regular     Foster   Scott  Zielinski     Gary
#
#       offLNm3   offFNm3 teamAbbr   ...      opptFTF diff_teamEFG%  \
# 0     Workman  Haywoode      WAS   ...     0.278481       -0.1000
# 1     Workman  Haywoode      CLE   ...     0.222222           NaN
# 2  Fitzgerald      Kane      BOS   ...     0.405063       -0.0349
# 3  Fitzgerald      Kane      MIA   ...     0.373333           NaN
# 4       Dalen      Eric      DAL   ...     0.402597       -0.0130
#
#   diff_opptEFG% diff_teamTO%  diff_opptTO%  diff_OREB%  diff_DREB%  \
# 0        0.1000      -7.5187        7.5187    -12.8205    -12.8205
# 1           NaN          NaN           NaN         NaN         NaN
# 2        0.0349       7.5714       -7.5714      5.6006      5.6006
# 3           NaN          NaN           NaN         NaN         NaN
# 4        0.0130      -1.9419        1.9419    -10.1087    -10.1087
#
#    diff_teamFTF  diff_opptFTF  outcome
# 0     -0.056259      0.056259      0.0
# 1           NaN           NaN      NaN
# 2     -0.031730      0.031730      0.0
# 3           NaN           NaN      NaN
# 4     -0.190833      0.190833      1.0
#
# [5 rows x 134 columns]

# %%
df.shape
# Out:
# (14758, 134)

# %%
# drop any rows with NaN values
df = df.dropna(how='any')

# %%
df.shape
# Out:
# (7377, 134)

# %%
target = df["outcome"]
target_names = ["loss", "win"]

# %%
# only focus on the columns for the four factors (four offense and four defense so technically 8 total)
# put that into new dataframe
df1 = df[['diff_teamEFG%','diff_opptEFG%', 'diff_teamTO%', 'diff_opptTO%', 'diff_OREB%', 'diff_DREB%', 'diff_teamFTF', 'diff_opptFTF', 'outcome']]
df1.head()
# Out:
#    diff_teamEFG%  diff_opptEFG%  diff_teamTO%  diff_opptTO%  diff_OREB%  \
# 0        -0.1000         0.1000       -7.5187        7.5187    -12.8205
# 2        -0.0349         0.0349        7.5714       -7.5714      5.6006
# 4        -0.0130         0.0130       -1.9419        1.9419    -10.1087
# 6         0.0036        -0.0036        4.6433       -4.6433      5.7300
# 8         0.1108        -0.1108        9.1181       -9.1181     -3.8462
#
#    diff_DREB%  diff_teamFTF  diff_opptFTF  outcome
# 0    -12.8205     -0.056259      0.056259      0.0
# 2      5.6006     -0.031730      0.031730      0.0
# 4    -10.1087     -0.190833      0.190833      1.0
# 6      5.7300     -0.122059      0.122059      0.0
# 8     -3.8462     -0.003663      0.003663      1.0

# %%
# new dataframe with 'outcome' dropped
data = df1.drop("outcome", axis=1)
feature_names = data.columns
data.head()
# Out:
#    diff_teamEFG%  diff_opptEFG%  diff_teamTO%  diff_opptTO%  diff_OREB%  \
# 0        -0.1000         0.1000       -7.5187        7.5187    -12.8205
# 2        -0.0349         0.0349        7.5714       -7.5714      5.6006
# 4        -0.0130         0.0130       -1.9419        1.9419    -10.1087
# 6         0.0036        -0.0036        4.6433       -4.6433      5.7300
# 8         0.1108        -0.1108        9.1181       -9.1181     -3.8462
#
#    diff_DREB%  diff_teamFTF  diff_opptFTF
# 0    -12.8205     -0.056259      0.056259
# 2      5.6006     -0.031730      0.031730
# 4    -10.1087     -0.190833      0.190833
# 6      5.7300     -0.122059      0.122059
# 8     -3.8462     -0.003663      0.003663

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='linear', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %%
# Model Accuracy
print('Test Acc: %.3f' % model.score(X_test, y_test))
# Out:
# Test Acc: 0.945

# %%
# Calculate classification report
from sklearn.metrics import classification_report
predictions = model.predict(X_test)
print(classification_report(y_test, predictions,
                            target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         loss       0.96      0.95      0.95      1094
#          win       0.93      0.94      0.93       751
#
#    micro avg       0.94      0.94      0.94      1845
#    macro avg       0.94      0.94      0.94      1845
# weighted avg       0.94      0.94      0.94      1845

# %%
# create function to make predictions
#
# returns string 'Win' if road team is predicted to win
# returns string 'Loss' if road team is predicted to lose
def predict_outcome_win_loss(road_team_abbr, road_team_stats, home_team_stats):
    road_team_array = np.array(road_team_stats)
    home_team_array = np.array(home_team_stats)
    diffs = road_team_array - home_team_array
    diffs_l = [diffs]
    prediction = model.predict(diffs_l)
    print(prediction)
    if ((prediction==1.).all()==True):
        print('Prediction is a Win for ' + str(road_team_abbr))
        outcome = 'Win'
    else:
        print('Prediction is a Loss for ' + str(road_team_abbr))
        outcome = 'Loss'
    return outcome

# %%
#Testing out prediction manually for sanity check purposes
#will automate this later on in this notebook

# Game DEN at SAC
den_stats = [.524, .513, 12.1, 12.2, 27.5, 77.7, .186, .191]
sac_stats = [.531, .536, 11.6, 13.7, 22.0, 74.8, .173, .209]
result = predict_outcome_win_loss('DEN', den_stats, sac_stats)
print(result)
# Out:
# [1.]
# Prediction is a Win for DEN
# Win

# %% [markdown]
# Step 2: Web scraping to capture updated daily stats from basketball-reference.com

# %%
#teams list
teams = ['ATL', 'BOS', 'BRK', 'CHO', 'CHI', 'CLE', 'DAL', 'DEN', 'DET',
         'GSW', 'HOU', 'IND', 'LAC', 'LAL', 'MEM', 'MIA', 'MIL', 'MIN',
         'NOP', 'NYK', 'OKC', 'ORL', 'PHI', 'PHO', 'POR', 'SAC', 'SAS',
         'TOR', 'UTA', 'WAS']

# %%
# load web pages without loading images in selenium
from selenium import webdriver

chromeOptions = webdriver.ChromeOptions()
prefs = {'profile.managed_default_content_settings.images':2}
chromeOptions.add_experimental_option("prefs", prefs)
driver = webdriver.Chrome(chrome_options=chromeOptions)

executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False, options=chromeOptions)
# Out:
# C:\Users\zmsub\AppData\Local\Continuum\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: DeprecationWarning: use options instead of chrome_options
#   import sys

# %%
# loop to start the scraping of the stats
team_list = []
x = 0 
while x == 0:
    try:
        for team in teams:
            # URL
            url = r"https://www.basketball-reference.com/teams/" + team + "/2019.html"
            browser.visit(url)

            stat_list = []

            #Path to get titles of articles
            team_X = team
            oEfg_X = '//*[@id="team_misc"]/tbody/tr[1]/td[13]'
            dEfg_X = '//*[@id="team_misc"]/tbody/tr[1]/td[17]'
            oTOV_X = '//*[@id="team_misc"]/tbody/tr[1]/td[14]'
            dTOV_X = '//*[@id="team_misc"]/tbody/tr[1]/td[18]'
            oORB_X = '//*[@id="team_misc"]/tbody/tr[1]/td[15]'
            dDRB_X = '//*[@id="team_misc"]/tbody/tr[1]/td[19]'
            oFtByFga_X = '//*[@id="team_misc"]/tbody/tr[1]/td[16]'
            dFtByFga_X = '//*[@id="team_misc"]/tbody/tr[1]/td[20]'

            #Reading the results  
            abr = team_X
            stat_list.append(abr)
            oEfg = browser.find_by_xpath(oEfg_X).value
            stat_list.append(oEfg)
            dEfg = browser.find_by_xpath(dEfg_X).value
            stat_list.append(dEfg)
            oTOV = browser.find_by_xpath(oTOV_X).value
            stat_list.append(oTOV)
            dTOV = browser.find_by_xpath(dTOV_X).value
            stat_list.append(dTOV)
            oORB = browser.find_by_xpath(oORB_X).value
            stat_list.append(oORB)
            dDRB = browser.find_by_xpath(dDRB_X).value
            stat_list.append(dDRB)
            oFtByFga = browser.find_by_xpath(oFtByFga_X).value
            stat_list.append(oFtByFga)
            dFtByFga = browser.find_by_xpath(dFtByFga_X).value
            stat_list.append(dFtByFga)

            team_list.append(stat_list)
            print(team_list)
        x = 1
    except:
        print("try again")
# Out:
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179'], ['SAC', '.533', '.538', '11.4', '13.6', '22.0', '74.4', '.169', '.207']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179'], ['SAC', '.533', '.538', '11.4', '13.6', '22.0', '74.4', '.169', '.207'], ['SAS', '.533', '.524', '11.0', '11.5', '21.6', '78.5', '.204', '.173']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179'], ['SAC', '.533', '.538', '11.4', '13.6', '22.0', '74.4', '.169', '.207'], ['SAS', '.533', '.524', '11.0', '11.5', '21.6', '78.5', '.204', '.173'], ['TOR', '.539', '.509', '11.8', '12.5', '23.0', '76.2', '.194', '.185']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179'], ['SAC', '.533', '.538', '11.4', '13.6', '22.0', '74.4', '.169', '.207'], ['SAS', '.533', '.524', '11.0', '11.5', '21.6', '78.5', '.204', '.173'], ['TOR', '.539', '.509', '11.8', '12.5', '23.0', '76.2', '.194', '.185'], ['UTA', '.529', '.519', '13.6', '13.4', '21.9', '80.0', '.217', '.195']]
# [['ATL', '.511', '.541', '15.2', '13.3', '24.1', '76.8', '.191', '.232'], ['BOS', '.531', '.505', '11.5', '13.8', '22.5', '77.8', '.175', '.210'], ['BRK', '.526', '.523', '12.5', '11.4', '24.9', '76.6', '.214', '.202'], ['CHO', '.519', '.529', '10.7', '12.3', '21.6', '76.7', '.205', '.185'], ['CHI', '.499', '.524', '13.4', '12.2', '17.2', '76.1', '.172', '.186'], ['CLE', '.494', '.555', '11.8', '11.0', '24.5', '76.3', '.182', '.179'], ['DAL', '.522', '.520', '13.6', '12.3', '23.5', '77.8', '.236', '.185'], ['DEN', '.524', '.516', '11.9', '12.2', '27.9', '77.7', '.186', '.190'], ['DET', '.495', '.520', '12.6', '12.6', '25.4', '79.8', '.199', '.232'], ['GSW', '.553', '.516', '12.6', '11.1', '22.8', '78.1', '.202', '.202'], ['HOU', '.535', '.529', '12.3', '12.4', '25.2', '75.4', '.219', '.218'], ['IND', '.534', '.507', '13.1', '14.3', '22.2', '77.2', '.178', '.176'], ['LAC', '.528', '.508', '12.4', '10.5', '22.7', '75.4', '.268', '.221'], ['LAL', '.533', '.504', '13.3', '11.8', '21.6', '76.5', '.179', '.184'], ['MEM', '.511', '.514', '12.4', '14.4', '17.8', '77.5', '.206', '.237'], ['MIA', '.503', '.502', '12.6', '12.3', '26.4', '77.0', '.188', '.214'], ['MIL', '.554', '.502', '12.3', '11.6', '21.4', '81.1', '.194', '.171'], ['MIN', '.508', '.526', '11.2', '13.3', '24.4', '74.3', '.213', '.183'], ['NOP', '.535', '.531', '12.4', '11.4', '25.8', '76.7', '.214', '.202'], ['NYK', '.488', '.544', '11.5', '11.9', '24.0', '75.8', '.204', '.202'], ['OKC', '.505', '.506', '12.1', '15.1', '26.6', '78.1', '.188', '.196'], ['ORL', '.507', '.520', '12.0', '12.0', '20.1', '77.7', '.164', '.197'], ['PHI', '.530', '.503', '13.1', '11.0', '23.3', '78.8', '.246', '.214'], ['PHO', '.517', '.543', '14.0', '13.4', '20.3', '74.2', '.182', '.235'], ['POR', '.515', '.517', '12.5', '10.7', '25.2', '78.2', '.208', '.179'], ['SAC', '.533', '.538', '11.4', '13.6', '22.0', '74.4', '.169', '.207'], ['SAS', '.533', '.524', '11.0', '11.5', '21.6', '78.5', '.204', '.173'], ['TOR', '.539', '.509', '11.8', '12.5', '23.0', '76.2', '.194', '.185'], ['UTA', '.529', '.519', '13.6', '13.4', '21.9', '80.0', '.217', '.195'], ['WAS', '.523', '.539', '11.9', '13.7', '20.2', '72.8', '.208', '.215']]

# %%
# Create a dataframe that has updated stats for all of the teams
stats_df = pd.DataFrame(team_list)
stats_df.columns = ['Team_abbr','Offense_eFG','Defense_eFG','Offense_TOV','Defense_TOV','Offense_ORB','Defense_DRB','Offense_FtFga','Defense_FtFga']
stats_df
# Out:
#    Team_abbr Offense_eFG Defense_eFG Offense_TOV Defense_TOV Offense_ORB  \
# 0        ATL        .511        .541        15.2        13.3        24.1
# 1        BOS        .531        .505        11.5        13.8        22.5
# 2        BRK        .526        .523        12.5        11.4        24.9
# 3        CHO        .519        .529        10.7        12.3        21.6
# 4        CHI        .499        .524        13.4        12.2        17.2
# 5        CLE        .494        .555        11.8        11.0        24.5
# 6        DAL        .522        .520        13.6        12.3        23.5
# 7        DEN        .524        .516        11.9        12.2        27.9
# 8        DET        .495        .520        12.6        12.6        25.4
# 9        GSW        .553        .516        12.6        11.1        22.8
# 10       HOU        .535        .529        12.3        12.4        25.2
# 11       IND        .534        .507        13.1        14.3        22.2
# 12       LAC        .528        .508        12.4        10.5        22.7
# 13       LAL        .533        .504        13.3        11.8        21.6
# 14       MEM        .511        .514        12.4        14.4        17.8
# 15       MIA        .503        .502        12.6        12.3        26.4
# 16       MIL        .554        .502        12.3        11.6        21.4
# 17       MIN        .508        .526        11.2        13.3        24.4
# 18       NOP        .535        .531        12.4        11.4        25.8
# 19       NYK        .488        .544        11.5        11.9        24.0
# 20       OKC        .505        .506        12.1        15.1        26.6
# 21       ORL        .507        .520        12.0        12.0        20.1
# 22       PHI        .530        .503        13.1        11.0        23.3
# 23       PHO        .517        .543        14.0        13.4        20.3
# 24       POR        .515        .517        12.5        10.7        25.2
# 25       SAC        .533        .538        11.4        13.6        22.0
# 26       SAS        .533        .524        11.0        11.5        21.6
# 27       TOR        .539        .509        11.8        12.5        23.0
# 28       UTA        .529        .519        13.6        13.4        21.9
# 29       WAS        .523        .539        11.9        13.7        20.2
#
#    Defense_DRB Offense_FtFga Defense_FtFga
# 0         76.8          .191          .232
# 1         77.8          .175          .210
# 2         76.6          .214          .202
# 3         76.7          .205          .185
# 4         76.1          .172          .186
# 5         76.3          .182          .179
# 6         77.8          .236          .185
# 7         77.7          .186          .190
# 8         79.8          .199          .232
# 9         78.1          .202          .202
# 10        75.4          .219          .218
# 11        77.2          .178          .176
# 12        75.4          .268          .221
# 13        76.5          .179          .184
# 14        77.5          .206          .237
# 15        77.0          .188          .214
# 16        81.1          .194          .171
# 17        74.3          .213          .183
# 18        76.7          .214          .202
# 19        75.8          .204          .202
# 20        78.1          .188          .196
# 21        77.7          .164          .197
# 22        78.8          .246          .214
# 23        74.2          .182          .235
# 24        78.2          .208          .179
# 25        74.4          .169          .207
# 26        78.5          .204          .173
# 27        76.2          .194          .185
# 28        80.0          .217          .195
# 29        72.8          .208          .215

# %% [markdown]
# Step 3: Update database (sqlite file) with 8 factors for each team (in 'stats' table)

# %%
# setup database connection
stats_engine = create_engine('sqlite:///db/schedule_abr.sqlite')
# send stats dataframe to stats table in database file
stats_df.to_sql('stats', stats_engine, if_exists='replace', index=False)

# %%
# test that we can query from stats table in db
stats_sql_df = pd.read_sql_query('SELECT * FROM stats',stats_engine)
stats_sql_df.head()
# Out:
#   Team_abbr Offense_eFG Defense_eFG Offense_TOV Defense_TOV Offense_ORB  \
# 0       ATL        .511        .541        15.2        13.3        24.1
# 1       BOS        .531        .505        11.5        13.8        22.5
# 2       BRK        .526        .523        12.5        11.4        24.9
# 3       CHO        .519        .529        10.7        12.3        21.6
# 4       CHI        .499        .524        13.4        12.2        17.2
#
#   Defense_DRB Offense_FtFga Defense_FtFga
# 0        76.8          .191          .232
# 1        77.8          .175          .210
# 2        76.6          .214          .202
# 3        76.7          .205          .185
# 4        76.1          .172          .186

# %%
# NEED TO SET PRIMARY KEY after to_sql is done so that later sqlalchemy can interact with the stats table

import sqlite3
#connect to the database
conn = sqlite3.connect('db/schedule_abr.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE stats RENAME TO old_stats;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE stats (Team_abbr text NOT NULL PRIMARY KEY,
                            Offense_eFG REAL NOT NULL,
                            Defense_eFG REAL NOT NULL,
                            Offense_TOV REAL NOT NULL,
                            Defense_TOV REAL NOT NULL,
                            Offense_ORB REAL NOT NULL,
                            Defense_DRB REAL NOT NULL,
                            Offense_FtFga REAL NOT NULL,
                            Defense_FtFga REAL NULL);

    INSERT INTO stats SELECT * FROM old_stats;

    DROP TABLE old_stats;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

# %% [markdown]
# Step 4: Find out each game that is being played today from database

# %%
# setup database connection
schedule_engine = create_engine('sqlite:///db/schedule_abr.sqlite')
# test that we can query from nba_2018_2019_schedule_logo table in database file
schedule_sql_df = pd.read_sql_query('SELECT * FROM nba_2018_2019_schedule_logo',schedule_engine)
schedule_sql_df.head()
# Out:
#    game_id        date      time                 location  \
# 0        1  10/16/2018   8:00 PM                TD Garden
# 1        2  10/16/2018  10:30 PM             ORACLE Arena
# 2        3  10/17/2018   7:00 PM          Spectrum Center
# 3        4  10/17/2018   7:00 PM     Little Caesars Arena
# 4        5  10/17/2018   7:00 PM  Bankers Life Fieldhouse
#
#                home_team              road_team home_score road_score  \
# 0         Boston Celtics     Philadelphia 76ers        105         87
# 1  Golden State Warriors  Oklahoma City Thunder        108        100
# 2      Charlotte Hornets        Milwaukee Bucks        112        113
# 3        Detroit Pistons          Brooklyn Nets        103        100
# 4         Indiana Pacers      Memphis Grizzlies        111         83
#
#       result home_team_abr road_team_abr road_win_prediction  \
# 0   105 - 87           BOS           PHI                Loss
# 1  108 - 100           GSW           OKC                Loss
# 2  112 - 113           CHO           MIL                Loss
# 3  103 - 100           DET           BRK                Loss
# 4   111 - 83           IND           MEM                Loss
#
#                                       home_team_logo  \
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...

# %%
# function to get today's date in same format as 'date' column of nba_2018_2019_schedule_logo table in database
# format is mm/dd/yyyy example: 1/6/2019

def get_todays_date():
    today = str(date.today())
    todays_date = date.today().strftime('%m/%d/%Y')
    print(todays_date)
    todays_date_month_first_two = todays_date[0:2]
    print(todays_date_month_first_two)
    newstr = todays_date_month_first_two
    if todays_date_month_first_two[0] == '0':
        newstr = todays_date_month_first_two.replace("0", "")
    print(newstr)
    todays_date_day_first_two = todays_date[3:5]
    print(todays_date_day_first_two)
    newstr2 = todays_date_day_first_two
    if todays_date_day_first_two[0] == '0':
        newstr2 = todays_date_day_first_two.replace("0", "")
    print(newstr2)
    newstr3 = todays_date[5:]
    final_date_string = newstr + '/' + newstr2 + newstr3
    return final_date_string

# %%
# test out function to get today's date
schedule_date = get_todays_date()
schedule_date
# Out:
# 01/07/2019
# 01
# 1
# 07
# 7
# '1/7/2019'

# %%
# function to get only today's games from schedule table into a dataframe
# this queries database

def get_todays_games(sch_date):
    cmd1 = 'SELECT * FROM nba_2018_2019_schedule_logo WHERE date='
    print(cmd1)
    cmd2 = "'"
    print(cmd2)
    cmd3 = "'"
    print(cmd3)
    cmd = cmd1 + cmd2 + schedule_date + cmd3
    print(cmd)
    schedule_today_df = pd.read_sql_query(cmd,schedule_engine)
    return schedule_today_df

# %%
# get only today's games into a dataframe
todays_games_df = get_todays_games(schedule_date)
todays_games_df
# Out:
# SELECT * FROM nba_2018_2019_schedule_logo WHERE date=
# '
# '
# SELECT * FROM nba_2018_2019_schedule_logo WHERE date='1/7/2019'
#    game_id      date      time                  location  \
# 0      591  1/7/2019   7:00 PM      Little Caesars Arena
# 1      592  1/7/2019   7:30 PM                 TD Garden
# 2      593  1/7/2019   8:00 PM             Toyota Center
# 3      594  1/7/2019   8:00 PM              Fiserv Forum
# 4      595  1/7/2019   8:00 PM      Smoothie King Center
# 5      596  1/7/2019   8:30 PM  American Airlines Center
# 6      597  1/7/2019  10:00 PM               Moda Center
# 7      598  1/7/2019  10:00 PM           Golden 1 Center
#
#                 home_team           road_team home_score road_score result  \
# 0         Detroit Pistons   San Antonio Spurs
# 1          Boston Celtics       Brooklyn Nets
# 2         Houston Rockets      Denver Nuggets
# 3         Milwaukee Bucks           Utah Jazz
# 4    New Orleans Pelicans   Memphis Grizzlies
# 5        Dallas Mavericks  Los Angeles Lakers
# 6  Portland Trail Blazers     New York Knicks
# 7        Sacramento Kings       Orlando Magic
#
#   home_team_abr road_team_abr road_win_prediction  \
# 0           DET           SAS                Loss
# 1           BOS           BRK                Loss
# 2           HOU           DEN                Loss
# 3           MIL           UTA                Loss
# 4           NOP           MEM                Loss
# 5           DAL           LAL                Loss
# 6           POR           NYK                Loss
# 7           SAC           ORL                Loss
#
#                                       home_team_logo  \
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
# 5  https://www.nba.com/assets/logos/teams/primary...
# 6  https://www.nba.com/assets/logos/teams/primary...
# 7  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
# 5  https://www.nba.com/assets/logos/teams/primary...
# 6  https://www.nba.com/assets/logos/teams/primary...
# 7  https://www.nba.com/assets/logos/teams/primary...

# %% [markdown]
# Step 5:
#
# a) get updated stats into arrays for road and home team's for each game being played today
# b) run prediction for road team for each game being played today

# %%
# function to get updated stats for an individual team using stats dataframe

def capture_updated_stats(team_name, df):
    team_row = df.loc[df['Team_abbr'] == team_name]
    print('Capturing stats for ' + team_name)
    team_O_EFG = float(team_row.iloc[0][1])
    team_D_EFG = float(team_row.iloc[0][2])
    team_O_TOV = float(team_row.iloc[0][3])
    team_D_TOV = float(team_row.iloc[0][4])
    team_O_ORB = float(team_row.iloc[0][5])
    team_D_DRB = float(team_row.iloc[0][6])
    team_O_FTF = float(team_row.iloc[0][7])
    team_D_FTF = float(team_row.iloc[0][8])
    print('values after iloc and converting to float are...')
    print(team_O_EFG)
    print(team_D_EFG)
    print(team_O_TOV)
    print(team_D_TOV)
    print(team_O_ORB)
    print(team_D_DRB)
    print(team_O_FTF)
    print(team_D_FTF)
    team_stats_array = [team_O_EFG, team_D_EFG, team_O_TOV, team_D_TOV, team_O_ORB, team_D_DRB, team_O_FTF, team_D_FTF]
    return team_stats_array

# %%
# function to iterate through all rows of schedule dataframe
# capture stats for road team and home team
# prediction for road team is made ('Win' or 'Loss') and dataframe is modified

def prediction_iterrow(sch_df, sta_df):
    for (i, row) in sch_df.iterrows():
        home_team_abr_val = row['home_team_abr']
        road_team_abr_val = row['road_team_abr']
        road_win_prediction_val = row['road_win_prediction']
        print(home_team_abr_val, road_team_abr_val, road_win_prediction_val)
        road_team_stats = capture_updated_stats(road_team_abr_val,sta_df)
        print('Road team stats--------->')
        print(road_team_stats)
        home_team_stats = capture_updated_stats(home_team_abr_val,sta_df)
        print('Home team stats--------->')
        print(home_team_stats)
        our_prediction = predict_outcome_win_loss(road_team_abr_val, road_team_stats, home_team_stats)
        print(our_prediction)
        print('Our Prediction for ' + road_team_abr_val + ' vs. ' + home_team_abr_val + ' is: ' + our_prediction)
        sch_df.at[i,'road_win_prediction'] = our_prediction

# %%
# create a today's stats dataframe equal to stats_sql_df we had gotten from scraping earlier
todays_stats_df = stats_sql_df
todays_stats_df.head()
# Out:
#   Team_abbr Offense_eFG Defense_eFG Offense_TOV Defense_TOV Offense_ORB  \
# 0       ATL        .511        .541        15.2        13.3        24.1
# 1       BOS        .531        .505        11.5        13.8        22.5
# 2       BRK        .526        .523        12.5        11.4        24.9
# 3       CHO        .519        .529        10.7        12.3        21.6
# 4       CHI        .499        .524        13.4        12.2        17.2
#
#   Defense_DRB Offense_FtFga Defense_FtFga
# 0        76.8          .191          .232
# 1        77.8          .175          .210
# 2        76.6          .214          .202
# 3        76.7          .205          .185
# 4        76.1          .172          .186

# %%
# show today's games dataframe again
todays_games_df.head()
# Out:
#    game_id      date     time              location             home_team  \
# 0      591  1/7/2019  7:00 PM  Little Caesars Arena       Detroit Pistons
# 1      592  1/7/2019  7:30 PM             TD Garden        Boston Celtics
# 2      593  1/7/2019  8:00 PM         Toyota Center       Houston Rockets
# 3      594  1/7/2019  8:00 PM          Fiserv Forum       Milwaukee Bucks
# 4      595  1/7/2019  8:00 PM  Smoothie King Center  New Orleans Pelicans
#
#            road_team home_score road_score result home_team_abr road_team_abr  \
# 0  San Antonio Spurs                                        DET           SAS
# 1      Brooklyn Nets                                        BOS           BRK
# 2     Denver Nuggets                                        HOU           DEN
# 3          Utah Jazz                                        MIL           UTA
# 4  Memphis Grizzlies                                        NOP           MEM
#
#   road_win_prediction                                     home_team_logo  \
# 0                Loss  https://www.nba.com/assets/logos/teams/primary...
# 1                Loss  https://www.nba.com/assets/logos/teams/primary...
# 2                Loss  https://www.nba.com/assets/logos/teams/primary...
# 3                Loss  https://www.nba.com/assets/logos/teams/primary...
# 4                Loss  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...

# %%
# run function that will use todays_stats_df to modify road_win_prediction column in todays_games_df

prediction_iterrow(todays_games_df, todays_stats_df)
# Out:
# DET SAS Loss
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Road team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Home team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# [1.]
# Prediction is a Win for SAS
# Win
# Our Prediction for SAS vs. DET is: Win
# BOS BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for BRK
# Loss
# Our Prediction for BRK vs. BOS is: Loss
# HOU DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. HOU is: Win
# MIL UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for UTA
# Loss
# Our Prediction for UTA vs. MIL is: Loss
# NOP MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Home team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# [0.]
# Prediction is a Loss for MEM
# Loss
# Our Prediction for MEM vs. NOP is: Loss
# DAL LAL Loss
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Road team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Home team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# [1.]
# Prediction is a Win for LAL
# Win
# Our Prediction for LAL vs. DAL is: Win
# POR NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [0.]
# Prediction is a Loss for NYK
# Loss
# Our Prediction for NYK vs. POR is: Loss
# SAC ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. SAC is: Loss

# %%
# now road_win_prediction column in todays_games_df should be updated with our predictions
todays_games_df
# Out:
#    game_id      date      time                  location  \
# 0      591  1/7/2019   7:00 PM      Little Caesars Arena
# 1      592  1/7/2019   7:30 PM                 TD Garden
# 2      593  1/7/2019   8:00 PM             Toyota Center
# 3      594  1/7/2019   8:00 PM              Fiserv Forum
# 4      595  1/7/2019   8:00 PM      Smoothie King Center
# 5      596  1/7/2019   8:30 PM  American Airlines Center
# 6      597  1/7/2019  10:00 PM               Moda Center
# 7      598  1/7/2019  10:00 PM           Golden 1 Center
#
#                 home_team           road_team home_score road_score result  \
# 0         Detroit Pistons   San Antonio Spurs
# 1          Boston Celtics       Brooklyn Nets
# 2         Houston Rockets      Denver Nuggets
# 3         Milwaukee Bucks           Utah Jazz
# 4    New Orleans Pelicans   Memphis Grizzlies
# 5        Dallas Mavericks  Los Angeles Lakers
# 6  Portland Trail Blazers     New York Knicks
# 7        Sacramento Kings       Orlando Magic
#
#   home_team_abr road_team_abr road_win_prediction  \
# 0           DET           SAS                 Win
# 1           BOS           BRK                Loss
# 2           HOU           DEN                 Win
# 3           MIL           UTA                Loss
# 4           NOP           MEM                Loss
# 5           DAL           LAL                 Win
# 6           POR           NYK                Loss
# 7           SAC           ORL                Loss
#
#                                       home_team_logo  \
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
# 5  https://www.nba.com/assets/logos/teams/primary...
# 6  https://www.nba.com/assets/logos/teams/primary...
# 7  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
# 5  https://www.nba.com/assets/logos/teams/primary...
# 6  https://www.nba.com/assets/logos/teams/primary...
# 7  https://www.nba.com/assets/logos/teams/primary...

# %%
# update SQL database in a table called 'today_predictions' with our predictions for today's games
schedule_abr_engine = create_engine('sqlite:///db/schedule_abr.sqlite')
todays_games_df.to_sql('today_predictions', schedule_abr_engine, if_exists='replace', index=False)

# %%
# test that we can query from today_predictions table in db
today_predictions_sql_df = pd.read_sql_query('SELECT * FROM today_predictions',schedule_abr_engine)
today_predictions_sql_df.head()
# Out:
#    game_id      date     time              location             home_team  \
# 0      591  1/7/2019  7:00 PM  Little Caesars Arena       Detroit Pistons
# 1      592  1/7/2019  7:30 PM             TD Garden        Boston Celtics
# 2      593  1/7/2019  8:00 PM         Toyota Center       Houston Rockets
# 3      594  1/7/2019  8:00 PM          Fiserv Forum       Milwaukee Bucks
# 4      595  1/7/2019  8:00 PM  Smoothie King Center  New Orleans Pelicans
#
#            road_team home_score road_score result home_team_abr road_team_abr  \
# 0  San Antonio Spurs                                        DET           SAS
# 1      Brooklyn Nets                                        BOS           BRK
# 2     Denver Nuggets                                        HOU           DEN
# 3          Utah Jazz                                        MIL           UTA
# 4  Memphis Grizzlies                                        NOP           MEM
#
#   road_win_prediction                                     home_team_logo  \
# 0                 Win  https://www.nba.com/assets/logos/teams/primary...
# 1                Loss  https://www.nba.com/assets/logos/teams/primary...
# 2                 Win  https://www.nba.com/assets/logos/teams/primary...
# 3                Loss  https://www.nba.com/assets/logos/teams/primary...
# 4                Loss  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...

# %%
# NEED TO SET PRIMARY KEY after to_sql is done so that later sqlalchemy can interact with the today_predictions table

import sqlite3
#connect to the database
conn = sqlite3.connect('db/schedule_abr.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE today_predictions RENAME TO old_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE today_predictions (game_id INTEGER NOT NULL PRIMARY KEY,
                            date text NOT NULL,
                            time text NOT NULL,
                            location text NOT NULL,
                            home_team text NOT NULL,
                            road_team text NOT NULL,
                            home_score INTEGER NOT NULL,
                            road_score INTEGER NOT NULL,
                            result text NOT NULL,
                            home_team_abr text NOT NULL,
                            road_team_abr text NOT NULL,
                            road_win_prediction text NOT NULL,
                            home_team_logo text NOT NULL,
                            road_team_logo text NOT NULL);

    INSERT INTO today_predictions SELECT * FROM old_table;

    DROP TABLE old_table;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()

# %% [markdown]
# Step 6:
#
# a) get updated stats into arrays for road and home team's for each game in 2019 (rest of season)
# b) run prediction for road team for each game being played in 2019 (rest of season)

# %%
# create a current stats dataframe equal to stats_sql_df we had gotten from scraping earlier
current_stats_df = stats_sql_df
current_stats_df.head()
# Out:
#   Team_abbr Offense_eFG Defense_eFG Offense_TOV Defense_TOV Offense_ORB  \
# 0       ATL        .511        .541        15.2        13.3        24.1
# 1       BOS        .531        .505        11.5        13.8        22.5
# 2       BRK        .526        .523        12.5        11.4        24.9
# 3       CHO        .519        .529        10.7        12.3        21.6
# 4       CHI        .499        .524        13.4        12.2        17.2
#
#   Defense_DRB Offense_FtFga Defense_FtFga
# 0        76.8          .191          .232
# 1        77.8          .175          .210
# 2        76.6          .214          .202
# 3        76.7          .205          .185
# 4        76.1          .172          .186

# %%
# function to get a year's games from schedule table into a dataframe
# this queries database

def get_year_games(year):
    cmd1 = 'SELECT game_id, date, home_team, road_team, home_team_abr, road_team_abr, road_win_prediction, home_team_logo, road_team_logo FROM nba_2018_2019_schedule_logo WHERE substr(date, 5, 4)='
    print(cmd1)
    cmd2 = "'"
    print(cmd2)
    cmd3 = "'"
    print(cmd3)
    cmd4 = 'or substr(date, 6, 4)='
    print(cmd4)
    cmd5 = "'"
    print(cmd2)
    cmd6 = "'"
    print(cmd3)
    cmd = cmd1 + cmd2 + year + cmd3 + cmd4 + cmd5 + year + cmd6
    print(cmd)
    schedule_year_df = pd.read_sql_query(cmd,schedule_engine)
    return schedule_year_df

# %%
# get 2019's games into a dataframe
season_year = '2019'
year_games_df = get_year_games(season_year)
year_games_df.head()
# Out:
# SELECT game_id, date, home_team, road_team, home_team_abr, road_team_abr, road_win_prediction, home_team_logo, road_team_logo FROM nba_2018_2019_schedule_logo WHERE substr(date, 5, 4)=
# '
# '
# or substr(date, 6, 4)=
# '
# '
# SELECT game_id, date, home_team, road_team, home_team_abr, road_team_abr, road_win_prediction, home_team_logo, road_team_logo FROM nba_2018_2019_schedule_logo WHERE substr(date, 5, 4)='2019'or substr(date, 6, 4)='2019'
#    game_id      date         home_team               road_team home_team_abr  \
# 0      549  1/1/2019   Toronto Raptors               Utah Jazz           TOR
# 1      550  1/1/2019   Milwaukee Bucks         Detroit Pistons           MIL
# 2      551  1/1/2019    Denver Nuggets         New York Knicks           DEN
# 3      552  1/1/2019  Sacramento Kings  Portland Trail Blazers           SAC
# 4      553  1/1/2019       LA Clippers      Philadelphia 76ers           LAC
#
#   road_team_abr road_win_prediction  \
# 0           UTA                Loss
# 1           DET                Loss
# 2           NYK                Loss
# 3           POR                Loss
# 4           PHI                Loss
#
#                                       home_team_logo  \
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...

# %%
# run function that will use current_stats_df to modify road_win_prediction column in year_games_df

prediction_iterrow(year_games_df, current_stats_df)
# Out:
# TOR UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Home team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# [0.]
# Prediction is a Loss for UTA
# Loss
# Our Prediction for UTA vs. TOR is: Loss
# MIL DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for DET
# Loss
# Our Prediction for DET vs. MIL is: Loss
# DEN NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Home team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# [0.]
# Prediction is a Loss for NYK
# Loss
# Our Prediction for NYK vs. DEN is: Loss
# SAC POR Loss
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Road team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [0.]
# Prediction is a Loss for POR
# Loss
# Our Prediction for POR vs. SAC is: Loss
# LAC PHI Loss
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Road team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Home team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# [1.]
# Prediction is a Win for PHI
# Win
# Our Prediction for PHI vs. LAC is: Win
# CHO DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Home team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# [0.]
# Prediction is a Loss for DAL
# Loss
# Our Prediction for DAL vs. CHO is: Loss
# CLE MIA Loss
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Road team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Home team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# [1.]
# Prediction is a Win for MIA
# Win
# Our Prediction for MIA vs. CLE is: Win
# WAS ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Home team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. WAS is: Loss
# BRK NOP Loss
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Road team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Home team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# [1.]
# Prediction is a Win for NOP
# Win
# Our Prediction for NOP vs. BRK is: Win
# BOS MIN Loss
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Road team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for MIN
# Loss
# Our Prediction for MIN vs. BOS is: Loss
# CHI ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Home team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# [1.]
# Prediction is a Win for ORL
# Win
# Our Prediction for ORL vs. CHI is: Win
# MEM DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Home team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# [0.]
# Prediction is a Loss for DET
# Loss
# Our Prediction for DET vs. MEM is: Loss
# PHO PHI Loss
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Road team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Home team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# [1.]
# Prediction is a Win for PHI
# Win
# Our Prediction for PHI vs. PHO is: Win
# LAL OKC Loss
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Road team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [1.]
# Prediction is a Win for OKC
# Win
# Our Prediction for OKC vs. LAL is: Win
# SAS TOR Loss
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Road team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Home team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# [1.]
# Prediction is a Win for TOR
# Win
# Our Prediction for TOR vs. SAS is: Win
# SAC DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. SAC is: Win
# GSW HOU Loss
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Road team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Home team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# [0.]
# Prediction is a Loss for HOU
# Loss
# Our Prediction for HOU vs. GSW is: Loss
# CLE UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Home team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# [1.]
# Prediction is a Win for UTA
# Win
# Our Prediction for UTA vs. CLE is: Win
# BOS DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for DAL
# Loss
# Our Prediction for DAL vs. BOS is: Loss
# MIA WAS Loss
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Road team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Home team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# [0.]
# Prediction is a Loss for WAS
# Loss
# Our Prediction for WAS vs. MIA is: Loss
# CHI IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Home team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# [1.]
# Prediction is a Win for IND
# Win
# Our Prediction for IND vs. CHI is: Win
# MEM BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Home team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# [1.]
# Prediction is a Win for BRK
# Win
# Our Prediction for BRK vs. MEM is: Win
# MIN ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Home team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. MIN is: Loss
# MIL ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. MIL is: Loss
# PHO LAC Loss
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Road team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Home team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# [1.]
# Prediction is a Win for LAC
# Win
# Our Prediction for LAC vs. PHO is: Win
# LAL NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [0.]
# Prediction is a Loss for NYK
# Loss
# Our Prediction for NYK vs. LAL is: Loss
# POR OKC Loss
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Road team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [1.]
# Prediction is a Win for OKC
# Win
# Our Prediction for OKC vs. POR is: Win
# DEN CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Home team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# [0.]
# Prediction is a Loss for CHO
# Loss
# Our Prediction for CHO vs. DEN is: Loss
# DET UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Home team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# [1.]
# Prediction is a Win for UTA
# Win
# Our Prediction for UTA vs. DET is: Win
# PHI DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Home team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# [0.]
# Prediction is a Loss for DAL
# Loss
# Our Prediction for DAL vs. PHI is: Loss
# CLE NOP Loss
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Road team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Home team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# [1.]
# Prediction is a Win for NOP
# Win
# Our Prediction for NOP vs. CLE is: Win
# MIL TOR Loss
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Road team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for TOR
# Loss
# Our Prediction for TOR vs. MIL is: Loss
# SAS MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Home team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# [0.]
# Prediction is a Loss for MEM
# Loss
# Our Prediction for MEM vs. SAS is: Loss
# POR HOU Loss
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Road team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [1.]
# Prediction is a Win for HOU
# Win
# Our Prediction for HOU vs. POR is: Win
# SAC GSW Loss
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Road team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [1.]
# Prediction is a Win for GSW
# Win
# Our Prediction for GSW vs. SAC is: Win
# CHI BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Home team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# [1.]
# Prediction is a Win for BRK
# Win
# Our Prediction for BRK vs. CHI is: Win
# MIN LAL Loss
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Road team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Home team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# [1.]
# Prediction is a Win for LAL
# Win
# Our Prediction for LAL vs. MIN is: Win
# LAC ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Home team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. LAC is: Loss
# ATL MIA Loss
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Road team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Home team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# [1.]
# Prediction is a Win for MIA
# Win
# Our Prediction for MIA vs. ATL is: Win
# OKC WAS Loss
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Road team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Home team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# [0.]
# Prediction is a Loss for WAS
# Loss
# Our Prediction for WAS vs. OKC is: Loss
# TOR IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Home team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# [0.]
# Prediction is a Loss for IND
# Loss
# Our Prediction for IND vs. TOR is: Loss
# PHO CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Home team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# [1.]
# Prediction is a Win for CHO
# Win
# Our Prediction for CHO vs. PHO is: Win
# DET SAS Loss
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Road team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Home team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# [1.]
# Prediction is a Win for SAS
# Win
# Our Prediction for SAS vs. DET is: Win
# BOS BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for BRK
# Loss
# Our Prediction for BRK vs. BOS is: Loss
# HOU DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. HOU is: Win
# MIL UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for UTA
# Loss
# Our Prediction for UTA vs. MIL is: Loss
# NOP MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Home team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# [0.]
# Prediction is a Loss for MEM
# Loss
# Our Prediction for MEM vs. NOP is: Loss
# DAL LAL Loss
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Road team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Home team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# [1.]
# Prediction is a Win for LAL
# Win
# Our Prediction for LAL vs. DAL is: Win
# POR NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [0.]
# Prediction is a Loss for NYK
# Loss
# Our Prediction for NYK vs. POR is: Loss
# SAC ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. SAC is: Loss
# CLE IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Home team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# [1.]
# Prediction is a Win for IND
# Win
# Our Prediction for IND vs. CLE is: Win
# PHI WAS Loss
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Road team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Home team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# [0.]
# Prediction is a Loss for WAS
# Loss
# Our Prediction for WAS vs. PHI is: Loss
# MIA DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Home team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. MIA is: Win
# TOR ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Home team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. TOR is: Loss
# OKC MIN Loss
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Road team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Home team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# [0.]
# Prediction is a Loss for MIN
# Loss
# Our Prediction for MIN vs. OKC is: Loss
# PHO SAC Loss
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Road team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Home team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# [1.]
# Prediction is a Win for SAC
# Win
# Our Prediction for SAC vs. PHO is: Win
# GSW NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Home team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# [0.]
# Prediction is a Loss for NYK
# Loss
# Our Prediction for NYK vs. GSW is: Loss
# LAC CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Home team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# [0.]
# Prediction is a Loss for CHO
# Loss
# Our Prediction for CHO vs. LAC is: Loss
# BOS IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for IND
# Loss
# Our Prediction for IND vs. BOS is: Loss
# WAS PHI Loss
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Road team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Home team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# [1.]
# Prediction is a Win for PHI
# Win
# Our Prediction for PHI vs. WAS is: Win
# BRK ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Home team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. BRK is: Loss
# HOU MIL Loss
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Road team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [1.]
# Prediction is a Win for MIL
# Win
# Our Prediction for MIL vs. HOU is: Win
# MEM SAS Loss
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Road team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Home team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# [1.]
# Prediction is a Win for SAS
# Win
# Our Prediction for SAS vs. MEM is: Win
# NOP CLE Loss
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Road team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Home team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# [0.]
# Prediction is a Loss for CLE
# Loss
# Our Prediction for CLE vs. NOP is: Loss
# DAL PHO Loss
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Road team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Home team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# [0.]
# Prediction is a Loss for PHO
# Loss
# Our Prediction for PHO vs. DAL is: Loss
# UTA ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Home team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. UTA is: Loss
# POR CHI Loss
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Road team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [0.]
# Prediction is a Loss for CHI
# Loss
# Our Prediction for CHI vs. POR is: Loss
# LAL DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [0.]
# Prediction is a Loss for DET
# Loss
# Our Prediction for DET vs. LAL is: Loss
# MIA BOS Loss
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Road team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Home team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# [1.]
# Prediction is a Win for BOS
# Win
# Our Prediction for BOS vs. MIA is: Win
# DEN LAC Loss
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Road team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Home team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# [0.]
# Prediction is a Loss for LAC
# Loss
# Our Prediction for LAC vs. DEN is: Loss
# SAS OKC Loss
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Road team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Home team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# [1.]
# Prediction is a Win for OKC
# Win
# Our Prediction for OKC vs. SAS is: Win
# SAC DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [0.]
# Prediction is a Loss for DET
# Loss
# Our Prediction for DET vs. SAC is: Loss
# PHI ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Home team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. PHI is: Loss
# WAS MIL Loss
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Road team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Home team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# [1.]
# Prediction is a Win for MIL
# Win
# Our Prediction for MIL vs. WAS is: Win
# NYK IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Home team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# [1.]
# Prediction is a Win for IND
# Win
# Our Prediction for IND vs. NYK is: Win
# TOR BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Home team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# [0.]
# Prediction is a Loss for BRK
# Loss
# Our Prediction for BRK vs. TOR is: Loss
# HOU CLE Loss
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Road team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [0.]
# Prediction is a Loss for CLE
# Loss
# Our Prediction for CLE vs. HOU is: Loss
# MIN DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Home team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# [0.]
# Prediction is a Loss for DAL
# Loss
# Our Prediction for DAL vs. MIN is: Loss
# UTA LAL Loss
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Road team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Home team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# [0.]
# Prediction is a Loss for LAL
# Loss
# Our Prediction for LAL vs. UTA is: Loss
# POR CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [1.]
# Prediction is a Win for CHO
# Win
# Our Prediction for CHO vs. POR is: Win
# GSW CHI Loss
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Road team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Home team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# [0.]
# Prediction is a Loss for CHI
# Loss
# Our Prediction for CHI vs. GSW is: Loss
# LAC DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Home team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# [0.]
# Prediction is a Loss for DET
# Loss
# Our Prediction for DET vs. LAC is: Loss
# MIA MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Home team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# [0.]
# Prediction is a Loss for MEM
# Loss
# Our Prediction for MEM vs. MIA is: Loss
# ORL BOS Loss
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Road team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Home team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# [1.]
# Prediction is a Win for BOS
# Win
# Our Prediction for BOS vs. ORL is: Win
# MIN NOP Loss
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Road team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Home team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# [0.]
# Prediction is a Loss for NOP
# Loss
# Our Prediction for NOP vs. MIN is: Loss
# OKC SAS Loss
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Road team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Home team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# [0.]
# Prediction is a Loss for SAS
# Loss
# Our Prediction for SAS vs. OKC is: Loss
# PHO DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Home team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. PHO is: Win
# SAC CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [1.]
# Prediction is a Win for CHO
# Win
# Our Prediction for CHO vs. SAC is: Win
# UTA CHI Loss
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Road team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Home team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# [0.]
# Prediction is a Loss for CHI
# Loss
# Our Prediction for CHI vs. UTA is: Loss
# NYK PHI Loss
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Road team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Home team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# [1.]
# Prediction is a Win for PHI
# Win
# Our Prediction for PHI vs. NYK is: Win
# WAS TOR Loss
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Road team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Home team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# [1.]
# Prediction is a Win for TOR
# Win
# Our Prediction for TOR vs. WAS is: Win
# ATL MIL Loss
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Road team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Home team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# [1.]
# Prediction is a Win for MIL
# Win
# Our Prediction for MIL vs. ATL is: Win
# ORL HOU Loss
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Road team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Home team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# [1.]
# Prediction is a Win for HOU
# Win
# Our Prediction for HOU vs. ORL is: Win
# DAL GSW Loss
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Road team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Home team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# [1.]
# Prediction is a Win for GSW
# Win
# Our Prediction for GSW vs. DAL is: Win
# DEN POR Loss
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Road team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Home team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# [0.]
# Prediction is a Loss for POR
# Loss
# Our Prediction for POR vs. DEN is: Loss
# LAL CLE Loss
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Road team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [0.]
# Prediction is a Loss for CLE
# Loss
# Our Prediction for CLE vs. LAL is: Loss
# BRK BOS Loss
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Road team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Home team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# [1.]
# Prediction is a Win for BOS
# Win
# Our Prediction for BOS vs. BRK is: Win
# HOU MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [0.]
# Prediction is a Loss for MEM
# Loss
# Our Prediction for MEM vs. HOU is: Loss
# SAS CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Home team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# [0.]
# Prediction is a Loss for CHO
# Loss
# Our Prediction for CHO vs. SAS is: Loss
# UTA DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# ...
# [1.]
# Prediction is a Win for OKC
# Win
# Our Prediction for OKC vs. MIN is: Win
# DET CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Home team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# [1.]
# Prediction is a Win for CHO
# Win
# Our Prediction for CHO vs. DET is: Win
# IND BRK Loss
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Road team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Home team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# [0.]
# Prediction is a Loss for BRK
# Loss
# Our Prediction for BRK vs. IND is: Loss
# MEM DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Home team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# [1.]
# Prediction is a Win for DAL
# Win
# Our Prediction for DAL vs. MEM is: Win
# MIL ATL Loss
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Road team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for ATL
# Loss
# Our Prediction for ATL vs. MIL is: Loss
# HOU PHO Loss
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Road team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Home team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# [0.]
# Prediction is a Loss for PHO
# Loss
# Our Prediction for PHO vs. HOU is: Loss
# BOS ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Home team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. BOS is: Loss
# NYK WAS Loss
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Road team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Home team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# [1.]
# Prediction is a Win for WAS
# Win
# Our Prediction for WAS vs. NYK is: Win
# GSW LAC Loss
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Road team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Home team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# [0.]
# Prediction is a Loss for LAC
# Loss
# Our Prediction for LAC vs. GSW is: Loss
# POR DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. POR is: Win
# SAC NOP Loss
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Road team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Home team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# [1.]
# Prediction is a Win for NOP
# Win
# Our Prediction for NOP vs. SAC is: Win
# LAL UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [1.]
# Prediction is a Win for UTA
# Win
# Our Prediction for UTA vs. LAL is: Win
# CLE CHO Loss
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Road team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# Capturing stats for CLE
# values after iloc and converting to float are...
# 0.494
# 0.555
# 11.8
# 11.0
# 24.5
# 76.3
# 0.182
# 0.179
# Home team stats--------->
# [0.494, 0.555, 11.8, 11.0, 24.5, 76.3, 0.182, 0.179]
# [1.]
# Prediction is a Win for CHO
# Win
# Our Prediction for CHO vs. CLE is: Win
# DET MEM Loss
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Road team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Home team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# [1.]
# Prediction is a Win for MEM
# Win
# Our Prediction for MEM vs. DET is: Win
# WAS BOS Loss
# Capturing stats for BOS
# values after iloc and converting to float are...
# 0.531
# 0.505
# 11.5
# 13.8
# 22.5
# 77.8
# 0.175
# 0.21
# Road team stats--------->
# [0.531, 0.505, 11.5, 13.8, 22.5, 77.8, 0.175, 0.21]
# Capturing stats for WAS
# values after iloc and converting to float are...
# 0.523
# 0.539
# 11.9
# 13.7
# 20.2
# 72.8
# 0.208
# 0.215
# Home team stats--------->
# [0.523, 0.539, 11.9, 13.7, 20.2, 72.8, 0.208, 0.215]
# [1.]
# Prediction is a Win for BOS
# Win
# Our Prediction for BOS vs. WAS is: Win
# MIA PHI Loss
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Road team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Home team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# [1.]
# Prediction is a Win for PHI
# Win
# Our Prediction for PHI vs. MIA is: Win
# CHI NYK Loss
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Road team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Home team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# [1.]
# Prediction is a Win for NYK
# Win
# Our Prediction for NYK vs. CHI is: Win
# MIN TOR Loss
# Capturing stats for TOR
# values after iloc and converting to float are...
# 0.539
# 0.509
# 11.8
# 12.5
# 23.0
# 76.2
# 0.194
# 0.185
# Road team stats--------->
# [0.539, 0.509, 11.8, 12.5, 23.0, 76.2, 0.194, 0.185]
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Home team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# [1.]
# Prediction is a Win for TOR
# Win
# Our Prediction for TOR vs. MIN is: Win
# NOP GSW Loss
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Road team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# Capturing stats for NOP
# values after iloc and converting to float are...
# 0.535
# 0.531
# 12.4
# 11.4
# 25.8
# 76.7
# 0.214
# 0.202
# Home team stats--------->
# [0.535, 0.531, 12.4, 11.4, 25.8, 76.7, 0.214, 0.202]
# [1.]
# Prediction is a Win for GSW
# Win
# Our Prediction for GSW vs. NOP is: Win
# DAL PHO Loss
# Capturing stats for PHO
# values after iloc and converting to float are...
# 0.517
# 0.543
# 14.0
# 13.4
# 20.3
# 74.2
# 0.182
# 0.235
# Road team stats--------->
# [0.517, 0.543, 14.0, 13.4, 20.3, 74.2, 0.182, 0.235]
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Home team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# [0.]
# Prediction is a Loss for PHO
# Loss
# Our Prediction for PHO vs. DAL is: Loss
# UTA DEN Loss
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Road team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Home team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# [1.]
# Prediction is a Win for DEN
# Win
# Our Prediction for DEN vs. UTA is: Win
# OKC HOU Loss
# Capturing stats for HOU
# values after iloc and converting to float are...
# 0.535
# 0.529
# 12.3
# 12.4
# 25.2
# 75.4
# 0.219
# 0.218
# Road team stats--------->
# [0.535, 0.529, 12.3, 12.4, 25.2, 75.4, 0.219, 0.218]
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Home team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# [0.]
# Prediction is a Loss for HOU
# Loss
# Our Prediction for HOU vs. OKC is: Loss
# LAL POR Loss
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Road team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# Capturing stats for LAL
# values after iloc and converting to float are...
# 0.533
# 0.504
# 13.3
# 11.8
# 21.6
# 76.5
# 0.179
# 0.184
# Home team stats--------->
# [0.533, 0.504, 13.3, 11.8, 21.6, 76.5, 0.179, 0.184]
# [0.]
# Prediction is a Loss for POR
# Loss
# Our Prediction for POR vs. LAL is: Loss
# ATL IND Loss
# Capturing stats for IND
# values after iloc and converting to float are...
# 0.534
# 0.507
# 13.1
# 14.3
# 22.2
# 77.2
# 0.178
# 0.176
# Road team stats--------->
# [0.534, 0.507, 13.1, 14.3, 22.2, 77.2, 0.178, 0.176]
# Capturing stats for ATL
# values after iloc and converting to float are...
# 0.511
# 0.541
# 15.2
# 13.3
# 24.1
# 76.8
# 0.191
# 0.232
# Home team stats--------->
# [0.511, 0.541, 15.2, 13.3, 24.1, 76.8, 0.191, 0.232]
# [1.]
# Prediction is a Win for IND
# Win
# Our Prediction for IND vs. ATL is: Win
# BRK MIA Loss
# Capturing stats for MIA
# values after iloc and converting to float are...
# 0.503
# 0.502
# 12.6
# 12.3
# 26.4
# 77.0
# 0.188
# 0.214
# Road team stats--------->
# [0.503, 0.502, 12.6, 12.3, 26.4, 77.0, 0.188, 0.214]
# Capturing stats for BRK
# values after iloc and converting to float are...
# 0.526
# 0.523
# 12.5
# 11.4
# 24.9
# 76.6
# 0.214
# 0.202
# Home team stats--------->
# [0.526, 0.523, 12.5, 11.4, 24.9, 76.6, 0.214, 0.202]
# [1.]
# Prediction is a Win for MIA
# Win
# Our Prediction for MIA vs. BRK is: Win
# CHO ORL Loss
# Capturing stats for ORL
# values after iloc and converting to float are...
# 0.507
# 0.52
# 12.0
# 12.0
# 20.1
# 77.7
# 0.164
# 0.197
# Road team stats--------->
# [0.507, 0.52, 12.0, 12.0, 20.1, 77.7, 0.164, 0.197]
# Capturing stats for CHO
# values after iloc and converting to float are...
# 0.519
# 0.529
# 10.7
# 12.3
# 21.6
# 76.7
# 0.205
# 0.185
# Home team stats--------->
# [0.519, 0.529, 10.7, 12.3, 21.6, 76.7, 0.205, 0.185]
# [0.]
# Prediction is a Loss for ORL
# Loss
# Our Prediction for ORL vs. CHO is: Loss
# NYK DET Loss
# Capturing stats for DET
# values after iloc and converting to float are...
# 0.495
# 0.52
# 12.6
# 12.6
# 25.4
# 79.8
# 0.199
# 0.232
# Road team stats--------->
# [0.495, 0.52, 12.6, 12.6, 25.4, 79.8, 0.199, 0.232]
# Capturing stats for NYK
# values after iloc and converting to float are...
# 0.488
# 0.544
# 11.5
# 11.9
# 24.0
# 75.8
# 0.204
# 0.202
# Home team stats--------->
# [0.488, 0.544, 11.5, 11.9, 24.0, 75.8, 0.204, 0.202]
# [1.]
# Prediction is a Win for DET
# Win
# Our Prediction for DET vs. NYK is: Win
# PHI CHI Loss
# Capturing stats for CHI
# values after iloc and converting to float are...
# 0.499
# 0.524
# 13.4
# 12.2
# 17.2
# 76.1
# 0.172
# 0.186
# Road team stats--------->
# [0.499, 0.524, 13.4, 12.2, 17.2, 76.1, 0.172, 0.186]
# Capturing stats for PHI
# values after iloc and converting to float are...
# 0.53
# 0.503
# 13.1
# 11.0
# 23.3
# 78.8
# 0.246
# 0.214
# Home team stats--------->
# [0.53, 0.503, 13.1, 11.0, 23.3, 78.8, 0.246, 0.214]
# [0.]
# Prediction is a Loss for CHI
# Loss
# Our Prediction for CHI vs. PHI is: Loss
# MEM GSW Loss
# Capturing stats for GSW
# values after iloc and converting to float are...
# 0.553
# 0.516
# 12.6
# 11.1
# 22.8
# 78.1
# 0.202
# 0.202
# Road team stats--------->
# [0.553, 0.516, 12.6, 11.1, 22.8, 78.1, 0.202, 0.202]
# Capturing stats for MEM
# values after iloc and converting to float are...
# 0.511
# 0.514
# 12.4
# 14.4
# 17.8
# 77.5
# 0.206
# 0.237
# Home team stats--------->
# [0.511, 0.514, 12.4, 14.4, 17.8, 77.5, 0.206, 0.237]
# [1.]
# Prediction is a Win for GSW
# Win
# Our Prediction for GSW vs. MEM is: Win
# MIL OKC Loss
# Capturing stats for OKC
# values after iloc and converting to float are...
# 0.505
# 0.506
# 12.1
# 15.1
# 26.6
# 78.1
# 0.188
# 0.196
# Road team stats--------->
# [0.505, 0.506, 12.1, 15.1, 26.6, 78.1, 0.188, 0.196]
# Capturing stats for MIL
# values after iloc and converting to float are...
# 0.554
# 0.502
# 12.3
# 11.6
# 21.4
# 81.1
# 0.194
# 0.171
# Home team stats--------->
# [0.554, 0.502, 12.3, 11.6, 21.4, 81.1, 0.194, 0.171]
# [0.]
# Prediction is a Loss for OKC
# Loss
# Our Prediction for OKC vs. MIL is: Loss
# SAS DAL Loss
# Capturing stats for DAL
# values after iloc and converting to float are...
# 0.522
# 0.52
# 13.6
# 12.3
# 23.5
# 77.8
# 0.236
# 0.185
# Road team stats--------->
# [0.522, 0.52, 13.6, 12.3, 23.5, 77.8, 0.236, 0.185]
# Capturing stats for SAS
# values after iloc and converting to float are...
# 0.533
# 0.524
# 11.0
# 11.5
# 21.6
# 78.5
# 0.204
# 0.173
# Home team stats--------->
# [0.533, 0.524, 11.0, 11.5, 21.6, 78.5, 0.204, 0.173]
# [0.]
# Prediction is a Loss for DAL
# Loss
# Our Prediction for DAL vs. SAS is: Loss
# DEN MIN Loss
# Capturing stats for MIN
# values after iloc and converting to float are...
# 0.508
# 0.526
# 11.2
# 13.3
# 24.4
# 74.3
# 0.213
# 0.183
# Road team stats--------->
# [0.508, 0.526, 11.2, 13.3, 24.4, 74.3, 0.213, 0.183]
# Capturing stats for DEN
# values after iloc and converting to float are...
# 0.524
# 0.516
# 11.9
# 12.2
# 27.9
# 77.7
# 0.186
# 0.19
# Home team stats--------->
# [0.524, 0.516, 11.9, 12.2, 27.9, 77.7, 0.186, 0.19]
# [0.]
# Prediction is a Loss for MIN
# Loss
# Our Prediction for MIN vs. DEN is: Loss
# LAC UTA Loss
# Capturing stats for UTA
# values after iloc and converting to float are...
# 0.529
# 0.519
# 13.6
# 13.4
# 21.9
# 80.0
# 0.217
# 0.195
# Road team stats--------->
# [0.529, 0.519, 13.6, 13.4, 21.9, 80.0, 0.217, 0.195]
# Capturing stats for LAC
# values after iloc and converting to float are...
# 0.528
# 0.508
# 12.4
# 10.5
# 22.7
# 75.4
# 0.268
# 0.221
# Home team stats--------->
# [0.528, 0.508, 12.4, 10.5, 22.7, 75.4, 0.268, 0.221]
# [1.]
# Prediction is a Win for UTA
# Win
# Our Prediction for UTA vs. LAC is: Win
# POR SAC Loss
# Capturing stats for SAC
# values after iloc and converting to float are...
# 0.533
# 0.538
# 11.4
# 13.6
# 22.0
# 74.4
# 0.169
# 0.207
# Road team stats--------->
# [0.533, 0.538, 11.4, 13.6, 22.0, 74.4, 0.169, 0.207]
# Capturing stats for POR
# values after iloc and converting to float are...
# 0.515
# 0.517
# 12.5
# 10.7
# 25.2
# 78.2
# 0.208
# 0.179
# Home team stats--------->
# [0.515, 0.517, 12.5, 10.7, 25.2, 78.2, 0.208, 0.179]
# [0.]
# Prediction is a Loss for SAC
# Loss
# Our Prediction for SAC vs. POR is: Loss

# %%
# now road_win_prediction column in year_games_df should be updated with our predictions
year_games_df.head
# Out:
# <bound method NDFrame.head of      game_id       date               home_team               road_team  \
# 0        549   1/1/2019         Toronto Raptors               Utah Jazz
# 1        550   1/1/2019         Milwaukee Bucks         Detroit Pistons
# 2        551   1/1/2019          Denver Nuggets         New York Knicks
# 3        552   1/1/2019        Sacramento Kings  Portland Trail Blazers
# 4        553   1/1/2019             LA Clippers      Philadelphia 76ers
# 5        554   1/2/2019       Charlotte Hornets        Dallas Mavericks
# 6        555   1/2/2019     Cleveland Cavaliers              Miami Heat
# 7        556   1/2/2019      Washington Wizards           Atlanta Hawks
# 8        557   1/2/2019           Brooklyn Nets    New Orleans Pelicans
# 9        558   1/2/2019          Boston Celtics  Minnesota Timberwolves
# 10       559   1/2/2019           Chicago Bulls           Orlando Magic
# 11       560   1/2/2019       Memphis Grizzlies         Detroit Pistons
# 12       561   1/2/2019            Phoenix Suns      Philadelphia 76ers
# 13       562   1/2/2019      Los Angeles Lakers   Oklahoma City Thunder
# 14       563   1/3/2019       San Antonio Spurs         Toronto Raptors
# 15       564   1/3/2019        Sacramento Kings          Denver Nuggets
# 16       565   1/3/2019   Golden State Warriors         Houston Rockets
# 17       566   1/4/2019     Cleveland Cavaliers               Utah Jazz
# 18       567   1/4/2019          Boston Celtics        Dallas Mavericks
# 19       568   1/4/2019              Miami Heat      Washington Wizards
# 20       569   1/4/2019           Chicago Bulls          Indiana Pacers
# 21       570   1/4/2019       Memphis Grizzlies           Brooklyn Nets
# 22       571   1/4/2019  Minnesota Timberwolves           Orlando Magic
# 23       572   1/4/2019         Milwaukee Bucks           Atlanta Hawks
# 24       573   1/4/2019            Phoenix Suns             LA Clippers
# 25       574   1/4/2019      Los Angeles Lakers         New York Knicks
# 26       575   1/4/2019  Portland Trail Blazers   Oklahoma City Thunder
# 27       576   1/5/2019          Denver Nuggets       Charlotte Hornets
# 28       577   1/5/2019         Detroit Pistons               Utah Jazz
# 29       578   1/5/2019      Philadelphia 76ers        Dallas Mavericks
# ..       ...        ...                     ...                     ...
# 652     1201   4/7/2019         Milwaukee Bucks           Atlanta Hawks
# 653     1202   4/7/2019         Houston Rockets            Phoenix Suns
# 654     1203   4/7/2019          Boston Celtics           Orlando Magic
# 655     1204   4/7/2019         New York Knicks      Washington Wizards
# 656     1205   4/7/2019   Golden State Warriors             LA Clippers
# 657     1206   4/7/2019  Portland Trail Blazers          Denver Nuggets
# 658     1207   4/7/2019        Sacramento Kings    New Orleans Pelicans
# 659     1208   4/7/2019      Los Angeles Lakers               Utah Jazz
# 660     1209   4/9/2019     Cleveland Cavaliers       Charlotte Hornets
# 661     1210   4/9/2019         Detroit Pistons       Memphis Grizzlies
# 662     1211   4/9/2019      Washington Wizards          Boston Celtics
# 663     1212   4/9/2019              Miami Heat      Philadelphia 76ers
# 664     1213   4/9/2019           Chicago Bulls         New York Knicks
# 665     1214   4/9/2019  Minnesota Timberwolves         Toronto Raptors
# 666     1215   4/9/2019    New Orleans Pelicans   Golden State Warriors
# 667     1216   4/9/2019        Dallas Mavericks            Phoenix Suns
# 668     1217   4/9/2019               Utah Jazz          Denver Nuggets
# 669     1218   4/9/2019   Oklahoma City Thunder         Houston Rockets
# 670     1219   4/9/2019      Los Angeles Lakers  Portland Trail Blazers
# 671     1220  4/10/2019           Atlanta Hawks          Indiana Pacers
# 672     1221  4/10/2019           Brooklyn Nets              Miami Heat
# 673     1222  4/10/2019       Charlotte Hornets           Orlando Magic
# 674     1223  4/10/2019         New York Knicks         Detroit Pistons
# 675     1224  4/10/2019      Philadelphia 76ers           Chicago Bulls
# 676     1225  4/10/2019       Memphis Grizzlies   Golden State Warriors
# 677     1226  4/10/2019         Milwaukee Bucks   Oklahoma City Thunder
# 678     1227  4/10/2019       San Antonio Spurs        Dallas Mavericks
# 679     1228  4/10/2019          Denver Nuggets  Minnesota Timberwolves
# 680     1229  4/10/2019             LA Clippers               Utah Jazz
# 681     1230  4/10/2019  Portland Trail Blazers        Sacramento Kings
#
#     home_team_abr road_team_abr road_win_prediction  \
# 0             TOR           UTA                Loss
# 1             MIL           DET                Loss
# 2             DEN           NYK                Loss
# 3             SAC           POR                Loss
# 4             LAC           PHI                 Win
# 5             CHO           DAL                Loss
# 6             CLE           MIA                 Win
# 7             WAS           ATL                Loss
# 8             BRK           NOP                 Win
# 9             BOS           MIN                Loss
# 10            CHI           ORL                 Win
# 11            MEM           DET                Loss
# 12            PHO           PHI                 Win
# 13            LAL           OKC                 Win
# 14            SAS           TOR                 Win
# 15            SAC           DEN                 Win
# 16            GSW           HOU                Loss
# 17            CLE           UTA                 Win
# 18            BOS           DAL                Loss
# 19            MIA           WAS                Loss
# 20            CHI           IND                 Win
# 21            MEM           BRK                 Win
# 22            MIN           ORL                Loss
# 23            MIL           ATL                Loss
# 24            PHO           LAC                 Win
# 25            LAL           NYK                Loss
# 26            POR           OKC                 Win
# 27            DEN           CHO                Loss
# 28            DET           UTA                 Win
# 29            PHI           DAL                Loss
# ..            ...           ...                 ...
# 652           MIL           ATL                Loss
# 653           HOU           PHO                Loss
# 654           BOS           ORL                Loss
# 655           NYK           WAS                 Win
# 656           GSW           LAC                Loss
# 657           POR           DEN                 Win
# 658           SAC           NOP                 Win
# 659           LAL           UTA                 Win
# 660           CLE           CHO                 Win
# 661           DET           MEM                 Win
# 662           WAS           BOS                 Win
# 663           MIA           PHI                 Win
# 664           CHI           NYK                 Win
# 665           MIN           TOR                 Win
# 666           NOP           GSW                 Win
# 667           DAL           PHO                Loss
# 668           UTA           DEN                 Win
# 669           OKC           HOU                Loss
# 670           LAL           POR                Loss
# 671           ATL           IND                 Win
# 672           BRK           MIA                 Win
# 673           CHO           ORL                Loss
# 674           NYK           DET                 Win
# 675           PHI           CHI                Loss
# 676           MEM           GSW                 Win
# 677           MIL           OKC                Loss
# 678           SAS           DAL                Loss
# 679           DEN           MIN                Loss
# 680           LAC           UTA                 Win
# 681           POR           SAC                Loss
#
#                                         home_team_logo  \
# 0    https://www.nba.com/assets/logos/teams/primary...
# 1    https://www.nba.com/assets/logos/teams/primary...
# 2    https://www.nba.com/assets/logos/teams/primary...
# 3    https://www.nba.com/assets/logos/teams/primary...
# 4    https://www.nba.com/assets/logos/teams/primary...
# 5    https://www.nba.com/assets/logos/teams/primary...
# 6    https://www.nba.com/assets/logos/teams/primary...
# 7    https://www.nba.com/assets/logos/teams/primary...
# 8    https://www.nba.com/assets/logos/teams/primary...
# 9    https://www.nba.com/assets/logos/teams/primary...
# 10   https://www.nba.com/assets/logos/teams/primary...
# 11   https://www.nba.com/assets/logos/teams/primary...
# 12   https://www.nba.com/assets/logos/teams/primary...
# 13   https://www.nba.com/assets/logos/teams/primary...
# 14   https://www.nba.com/assets/logos/teams/primary...
# 15   https://www.nba.com/assets/logos/teams/primary...
# 16   https://www.nba.com/assets/logos/teams/primary...
# 17   https://www.nba.com/assets/logos/teams/primary...
# 18   https://www.nba.com/assets/logos/teams/primary...
# 19   https://www.nba.com/assets/logos/teams/primary...
# 20   https://www.nba.com/assets/logos/teams/primary...
# 21   https://www.nba.com/assets/logos/teams/primary...
# 22   https://www.nba.com/assets/logos/teams/primary...
# 23   https://www.nba.com/assets/logos/teams/primary...
# 24   https://www.nba.com/assets/logos/teams/primary...
# 25   https://www.nba.com/assets/logos/teams/primary...
# 26   https://www.nba.com/assets/logos/teams/primary...
# 27   https://www.nba.com/assets/logos/teams/primary...
# 28   https://www.nba.com/assets/logos/teams/primary...
# 29   https://www.nba.com/assets/logos/teams/primary...
# ..                                                 ...
# 652  https://www.nba.com/assets/logos/teams/primary...
# 653  https://www.nba.com/assets/logos/teams/primary...
# 654  https://www.nba.com/assets/logos/teams/primary...
# 655  https://www.nba.com/assets/logos/teams/primary...
# 656  https://www.nba.com/assets/logos/teams/primary...
# 657  https://www.nba.com/assets/logos/teams/primary...
# 658  https://www.nba.com/assets/logos/teams/primary...
# 659  https://www.nba.com/assets/logos/teams/primary...
# 660  https://www.nba.com/assets/logos/teams/primary...
# 661  https://www.nba.com/assets/logos/teams/primary...
# 662  https://www.nba.com/assets/logos/teams/primary...
# 663  https://www.nba.com/assets/logos/teams/primary...
# 664  https://www.nba.com/assets/logos/teams/primary...
# 665  https://www.nba.com/assets/logos/teams/primary...
# 666  https://www.nba.com/assets/logos/teams/primary...
# 667  https://www.nba.com/assets/logos/teams/primary...
# 668  https://www.nba.com/assets/logos/teams/primary...
# 669  https://www.nba.com/assets/logos/teams/primary...
# 670  https://www.nba.com/assets/logos/teams/primary...
# 671  https://www.nba.com/assets/logos/teams/primary...
# 672  https://www.nba.com/assets/logos/teams/primary...
# 673  https://www.nba.com/assets/logos/teams/primary...
# 674  https://www.nba.com/assets/logos/teams/primary...
# 675  https://www.nba.com/assets/logos/teams/primary...
# 676  https://www.nba.com/assets/logos/teams/primary...
# 677  https://www.nba.com/assets/logos/teams/primary...
# 678  https://www.nba.com/assets/logos/teams/primary...
# 679  https://www.nba.com/assets/logos/teams/primary...
# 680  https://www.nba.com/assets/logos/teams/primary...
# 681  https://www.nba.com/assets/logos/teams/primary...
#
#                                         road_team_logo
# 0    https://www.nba.com/assets/logos/teams/primary...
# 1    https://www.nba.com/assets/logos/teams/primary...
# 2    https://www.nba.com/assets/logos/teams/primary...
# 3    https://www.nba.com/assets/logos/teams/primary...
# 4    https://www.nba.com/assets/logos/teams/primary...
# 5    https://www.nba.com/assets/logos/teams/primary...
# 6    https://www.nba.com/assets/logos/teams/primary...
# 7    https://www.nba.com/assets/logos/teams/primary...
# 8    https://www.nba.com/assets/logos/teams/primary...
# 9    https://www.nba.com/assets/logos/teams/primary...
# 10   https://www.nba.com/assets/logos/teams/primary...
# 11   https://www.nba.com/assets/logos/teams/primary...
# 12   https://www.nba.com/assets/logos/teams/primary...
# 13   https://www.nba.com/assets/logos/teams/primary...
# 14   https://www.nba.com/assets/logos/teams/primary...
# 15   https://www.nba.com/assets/logos/teams/primary...
# 16   https://www.nba.com/assets/logos/teams/primary...
# 17   https://www.nba.com/assets/logos/teams/primary...
# 18   https://www.nba.com/assets/logos/teams/primary...
# 19   https://www.nba.com/assets/logos/teams/primary...
# 20   https://www.nba.com/assets/logos/teams/primary...
# 21   https://www.nba.com/assets/logos/teams/primary...
# 22   https://www.nba.com/assets/logos/teams/primary...
# 23   https://www.nba.com/assets/logos/teams/primary...
# 24   https://www.nba.com/assets/logos/teams/primary...
# 25   https://www.nba.com/assets/logos/teams/primary...
# 26   https://www.nba.com/assets/logos/teams/primary...
# 27   https://www.nba.com/assets/logos/teams/primary...
# 28   https://www.nba.com/assets/logos/teams/primary...
# 29   https://www.nba.com/assets/logos/teams/primary...
# ..                                                 ...
# 652  https://www.nba.com/assets/logos/teams/primary...
# 653  https://www.nba.com/assets/logos/teams/primary...
# 654  https://www.nba.com/assets/logos/teams/primary...
# 655  https://www.nba.com/assets/logos/teams/primary...
# 656  https://www.nba.com/assets/logos/teams/primary...
# 657  https://www.nba.com/assets/logos/teams/primary...
# 658  https://www.nba.com/assets/logos/teams/primary...
# 659  https://www.nba.com/assets/logos/teams/primary...
# 660  https://www.nba.com/assets/logos/teams/primary...
# 661  https://www.nba.com/assets/logos/teams/primary...
# 662  https://www.nba.com/assets/logos/teams/primary...
# 663  https://www.nba.com/assets/logos/teams/primary...
# 664  https://www.nba.com/assets/logos/teams/primary...
# 665  https://www.nba.com/assets/logos/teams/primary...
# 666  https://www.nba.com/assets/logos/teams/primary...
# 667  https://www.nba.com/assets/logos/teams/primary...
# 668  https://www.nba.com/assets/logos/teams/primary...
# 669  https://www.nba.com/assets/logos/teams/primary...
# 670  https://www.nba.com/assets/logos/teams/primary...
# 671  https://www.nba.com/assets/logos/teams/primary...
# 672  https://www.nba.com/assets/logos/teams/primary...
# 673  https://www.nba.com/assets/logos/teams/primary...
# 674  https://www.nba.com/assets/logos/teams/primary...
# 675  https://www.nba.com/assets/logos/teams/primary...
# 676  https://www.nba.com/assets/logos/teams/primary...
# 677  https://www.nba.com/assets/logos/teams/primary...
# 678  https://www.nba.com/assets/logos/teams/primary...
# 679  https://www.nba.com/assets/logos/teams/primary...
# 680  https://www.nba.com/assets/logos/teams/primary...
# 681  https://www.nba.com/assets/logos/teams/primary...
#
# [682 rows x 9 columns]>

# %%
# update SQL database in a table called 'year_predictions' with our predictions for the rest of season (year) games
year_schedule_abr_engine = create_engine('sqlite:///db/schedule_abr.sqlite')
year_games_df.to_sql('year_predictions', year_schedule_abr_engine, if_exists='replace', chunksize=75, index=False)

# %%
# test that we can query from year_predictions table in db
year_predictions_sql_df = pd.read_sql_query('SELECT * FROM year_predictions',schedule_abr_engine)
year_predictions_sql_df.head()
# Out:
#    game_id      date         home_team               road_team home_team_abr  \
# 0      549  1/1/2019   Toronto Raptors               Utah Jazz           TOR
# 1      550  1/1/2019   Milwaukee Bucks         Detroit Pistons           MIL
# 2      551  1/1/2019    Denver Nuggets         New York Knicks           DEN
# 3      552  1/1/2019  Sacramento Kings  Portland Trail Blazers           SAC
# 4      553  1/1/2019       LA Clippers      Philadelphia 76ers           LAC
#
#   road_team_abr road_win_prediction  \
# 0           UTA                Loss
# 1           DET                Loss
# 2           NYK                Loss
# 3           POR                Loss
# 4           PHI                 Win
#
#                                       home_team_logo  \
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...
#
#                                       road_team_logo
# 0  https://www.nba.com/assets/logos/teams/primary...
# 1  https://www.nba.com/assets/logos/teams/primary...
# 2  https://www.nba.com/assets/logos/teams/primary...
# 3  https://www.nba.com/assets/logos/teams/primary...
# 4  https://www.nba.com/assets/logos/teams/primary...

# %%
# NEED TO SET PRIMARY KEY after to_sql is done so that later sqlalchemy can interact with the today_predictions table

import sqlite3
#connect to the database
conn = sqlite3.connect('db/schedule_abr.sqlite')
c = conn.cursor()

c.executescript('''
    PRAGMA foreign_keys=off;

    BEGIN TRANSACTION;
    ALTER TABLE year_predictions RENAME TO old_year_table;

    /*create a new table with the same column names and types while
    defining a primary key for the desired column*/
    CREATE TABLE year_predictions (game_id INTEGER NOT NULL PRIMARY KEY,
                            date text NOT NULL,
                            home_team text NOT NULL,
                            road_team text NOT NULL,
                            home_team_abr text NOT NULL,
                            road_team_abr text NOT NULL,
                            road_win_prediction text NOT NULL,
                            home_team_logo text NOT NULL,
                            road_team_logo text NOT NULL);

    INSERT INTO year_predictions SELECT * FROM old_year_table;

    DROP TABLE old_year_table;
    COMMIT TRANSACTION;

    PRAGMA foreign_keys=on;''')

#close out the connection
c.close()
conn.close()
